# %%
import time

# User input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start execution time
start = time.time()

# Bubble Sort
for i in range(n - 1):
    for j in range(n - i - 1):
        if arr[j] > arr[j + 1]:
            temp = arr[j]
            arr[j] = arr[j + 1]
            arr[j + 1] = temp

# End execution time
end = time.time()

# Display sorted array
print("\nSorted Array:")
for i in range(n):
    print(arr[i], end=" ")

# Display execution time
print("\nExecution Time:", end - start, "seconds")

# Display complexity
print("Time Complexity: O(n²)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter the elements:
# 3
# 8
# 6
# 9
# 5
#
# Sorted Array:
# 3 5 6 8 9
# Execution Time: 0.00018715858459472656 seconds
# Time Complexity: O(n²)
# Space Complexity: O(1)

# %%
import time

# Quick Sort Function
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[0]
    left = []
    right = []

    for i in arr[1:]:
        if i <= pivot:
            left.append(i)
        else:
            right.append(i)

    return quick_sort(left) + [pivot] + quick_sort(right)

# User Input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter the elements:")
for i in range(n):
    num = int(input())
    arr.append(num)

# Start Execution Time
start = time.time()

# Call Quick Sort
sorted_arr = quick_sort(arr)

# End Execution Time
end = time.time()

# Display Sorted Array
print("\nSorted Array:")
for i in sorted_arr:
    print(i, end=" ")

# Display Execution Time
print("\n\nExecution Time:", end - start, "seconds")

# Display Time Complexity
print("Best Time Complexity: O(n log n)")
print("Average Time Complexity: O(n log n)")
print("Worst Time Complexity: O(n²)")
print("Space Complexity: O(n)")
# Out:
# Enter the number of elements: 5
# Enter the elements:
# 7
# 8
# 4
# 3
# 2
#
# Sorted Array:
# 2 3 4 7 8
#
# Execution Time: 0.00010251998901367188 seconds
# Best Time Complexity: O(n log n)
# Average Time Complexity: O(n log n)
# Worst Time Complexity: O(n²)
# Space Complexity: O(n)

# %%
import time

# Merge Sort Function
def merge_sort(arr):
    if len(arr) > 1:

        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]

        # Recursively sort both halves
        merge_sort(left)
        merge_sort(right)

        i = j = k = 0

        # Merge the two halves
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1

        # Copy remaining elements of left
        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        # Copy remaining elements of right
        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

# User Input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start Execution Time
start = time.time()

# Call Merge Sort
merge_sort(arr)

# End Execution Time
end = time.time()

# Display Sorted Array
print("\nSorted Array:")
for i in arr:
    print(i, end=" ")

# Display Execution Time
print("\n\nExecution Time:", end - start, "seconds")

# Display Time Complexity
print("Best Time Complexity: O(n log n)")
print("Average Time Complexity: O(n log n)")
print("Worst Time Complexity: O(n log n)")
print("Space Complexity: O(n)")
# Out:
# Enter the number of elements: 5
# Enter the elements:
# 4
# 6
# 3
# 8
# 5
#
# Sorted Array:
# 3 4 5 6 8
#
# Execution Time: 0.0001227855682373047 seconds
# Best Time Complexity: O(n log n)
# Average Time Complexity: O(n log n)
# Worst Time Complexity: O(n log n)
# Space Complexity: O(n)

# %%
import time

# User Input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start Execution Time
start = time.time()

# Selection Sort
for i in range(n):
    min_index = i

    for j in range(i + 1, n):
        if arr[j] < arr[min_index]:
            min_index = j

    arr[i], arr[min_index] = arr[min_index], arr[i]

# End Execution Time
end = time.time()

# Display Sorted Array
print("\nSorted Array:")
for i in arr:
    print(i, end=" ")

# Display Execution Time
print("\n\nExecution Time:", end - start, "seconds")

# Display Time Complexity
print("Best Time Complexity: O(n²)")
print("Average Time Complexity: O(n²)")
print("Worst Time Complexity: O(n²)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter the elements:
# 22
# 11
# 44
# 54
# 34
#
# Sorted Array:
# 11 22 34 44 54
#
# Execution Time: 0.0002009868621826172 seconds
# Best Time Complexity: O(n²)
# Average Time Complexity: O(n²)
# Worst Time Complexity: O(n²)
# Space Complexity: O(1)

# %%
import time

# User Input
n = int(input("Enter the number of elements: "))

arr = []

print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start Execution Time
start = time.time()

# Insertion Sort
for i in range(1, n):
    key = arr[i]
    j = i - 1

    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j = j - 1

    arr[j + 1] = key

# End Execution Time
end = time.time()

# Display Sorted Array
print("\nSorted Array:")
for i in arr:
    print(i, end=" ")

# Display Execution Time
print("\n\nExecution Time:", end - start, "seconds")

# Display Time Complexity
print("Best Time Complexity: O(n)")
print("Average Time Complexity: O(n²)")
print("Worst Time Complexity: O(n²)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter the elements:
# 12
# 3
# 45
# 6
# 78
#
# Sorted Array:
# 3 6 12 45 78
#
# Execution Time: 0.00019979476928710938 seconds
# Best Time Complexity: O(n)
# Average Time Complexity: O(n²)
# Worst Time Complexity: O(n²)
# Space Complexity: O(1)
